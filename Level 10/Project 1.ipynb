# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# Gender and Survived

# %%
pal = {1:"seagreen", 0:"red"}
sns.set(style="darkgrid")
plt.subplots(figsize = (8,5))
ax = sns.countplot(x = "Sex", 
                   hue="Survived",
                   data = pd.read_csv('train.csv'), 
                   linewidth=4, 
                   palette = pal
)

plt.title("Passenger Gender Distribution - Survived vs Not-survived", fontsize = 25, pad=40)
plt.xlabel("Sex", fontsize = 15);
plt.ylabel("# of Passenger Survived", fontsize = 15)

leg = ax.get_legend()
leg.set_title("Survived")
legs = leg.texts
legs[0].set_text("No")
legs[1].set_text("Yes")

# %% [markdown]
# Pclass and Survived

# %%
# Kernel Density Plot
fig = plt.figure(figsize=(8,5),)
train = pd.read_csv('train.csv')
ax=sns.kdeplot(train.Pclass[train.Survived == 0] , 
               color='r',
               fill=True,
               label='not survived')
ax=sns.kdeplot(train.loc[(train['Survived'] == 1),'Pclass'] , 
               color='g',
               fill=True, 
               label='survived', 
              )
plt.title('Passenger Class Distribution - Survived vs Non-Survived', fontsize = 25, pad = 40)
plt.ylabel("Frequency of Passenger Survived", fontsize = 15, labelpad = 20)
plt.xlabel("Passenger Class", fontsize = 15,labelpad =20)
## Converting xticks into words for better understanding
labels = ['Upper', 'Middle', 'Lower']
plt.xticks(sorted(train.Pclass.unique()), labels);

# %% [markdown]
# Fare and Survived

# %%
fig = plt.figure(figsize=(8,5),)
ax=sns.kdeplot(train.loc[(train['Survived'] == 0),'Fare'] , color='r',fill=True,label='not survived')
ax=sns.kdeplot(train.loc[(train['Survived'] == 1),'Fare'] , color='g',fill=True, label='survived')
plt.title('Fare Distribution Survived vs Non Survived', fontsize = 25, pad = 40)
plt.ylabel("Frequency of Passenger Survived", fontsize = 15, labelpad = 20)
plt.xlabel("Fare", fontsize = 15, labelpad = 20);

# %% [markdown]
# Age and Survived

# %%
fig = plt.figure(figsize=(8,5),)
ax=sns.kdeplot(train.loc[(train['Survived'] == 0),'Age'] , color='r',fill=True,label='not survived')
ax=sns.kdeplot(train.loc[(train['Survived'] == 1),'Age'] , color='g',fill=True, label='survived')
plt.title('Age Distribution - Surviver V.S. Non Survivors', fontsize = 25, pad = 40)
plt.xlabel("Age", fontsize = 15, labelpad = 20)
plt.ylabel('Frequency', fontsize = 15, labelpad= 20);

# %% [markdown]
# Combined Feature Relations

# %%
pal = {1:"seagreen", 0:"red"}
g = sns.FacetGrid(train, height=3, col="Sex", row="Survived", margin_titles=True, hue = "Survived",
                  palette=pal)
g = g.map(plt.hist, "Age", edgecolor = 'black');
g.fig.suptitle("Survived by Sex and Age", size = 25)
plt.subplots_adjust(top=0.90)

# %% [markdown]
# Correlation Matrix and Heatmap

# %%
non_numeric_cols = train.select_dtypes(include=['object']).columns
print(non_numeric_cols)
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df = train.copy()

# %%
train_numeric = df.select_dtypes(include=[np.number])

# %%
import numpy as np
mask = np.zeros_like(train_numeric.corr(), dtype=np.bool_)
mask[np.triu_indices_from(mask)] = True
sns.set_style('whitegrid')
plt.subplots(figsize = (8,6))
sns.heatmap(train_numeric.corr(), 
            annot=True,
            mask = mask,
            cmap = 'RdBu',
            linewidths=.9, 
            linecolor='white',
            fmt='.2g',
            center = 0,
            square=True)
plt.title("Correlations Among Features", y = 1.03,fontsize = 20, pad = 40);
