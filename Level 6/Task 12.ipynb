# %% [markdown]
# # QQ Plot

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

data = np.random.normal(loc=0, scale=1, size=60)

stats.probplot(data, dist="norm", plot=plt)
plt.title("QQ Plot for Normality Check")
plt.show()
